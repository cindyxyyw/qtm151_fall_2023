# %% [markdown]
# # Assignment 9

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size = "5">
# Print your Emory ID below

# %%
# Write your answer here:
print (2549813)
# Out:
# 2549813

# %% [markdown]
# <font size = "5">
#
# Import the "pandas", "sqlalchemy" and "URL" libraries <br>
# (See Lecture 19)

# %%
# Write your answer here:
import pandas as pd
import psycopg2
import sqlalchemy as sa
from sqlalchemy import create_engine
from   sqlalchemy import text

# %% [markdown]
# <font size = "5">
#
# Establish a connection to the SQL server and database ```formula1``` <br>
# from Python as in Lecture 18 using <br>
# ```URL()``` and ```create_engine()```

# %%
# Write your own code

url_server = URL.create(
    "postgresql",
    host = 'localhost',
    database = 'formula1',
    username = 'postgres',
    port = 5432,
    password  = '20040406')

connection = create_engine(url_server)

# %% [markdown]
# <font size = "5">
#
# In this homework, you will repeat the exercises in <br>
# Assignment 8, this time accessing SQL indirectly <br>
# from Python
#
# <font size = "3">
#
# - For (a)-(e) read the section <br>
# on "Escape Characters" carefully and how to write <br>
# strings in multiple lines
# - Remember that there is a special syntax for <br>
# column names that have capital letters

# %% [markdown]
# <font size = "5">
#
# (a) Import "lap_times.csv" and "drivers.csv"
#
# <font size = "3">
#
# - Import the data using ```pd.read_csv()```
# - Upload to the server using  ```.to_sql()```
# - Upload the CSV files to the server, even if you already have the tables

# %%
# Write your own code
lap_times  = pd.read_csv("data_raw/lap_times.csv")
drivers    = pd.read_csv("data_raw/drivers.csv")

lap_times.to_sql('races_sql',connection, if_exists='replace')
drivers.to_sql('races_sql',connection, if_exists='replace')
# Out:
# 857

# %% [markdown]
# <font size = "5">
#
# (b) Subset and sort
#
# <font size = "3">
#
# - In this exercise use the function ```.read_sql()```
# - Use ```WHERE``` to get a subset of "drivers" with
# ```nationality = 'American'```
# - Chain this with ```ORDER BY surname ASC``` to sort in <br>
# ascending order
#
# HINT: Use single quotes inside a string as in Lecture 20

# %%
# Write your own code

pd.read_sql(text("SELECT *  \
                 FROM drivers \
                 WHERE nationality = 'American' \
                 ORDER BY surname ASC;"),connection)
# Out:
#      driverId       driverRef number code forename     surname         dob  \
# 0         796            ader     \N   \N     Walt        Ader  1913-12-15
# 1         615      agabashian     \N   \N     Fred  Agabashian  1913-08-21
# 2         517           amick     \N   \N      Red       Amick  1929-01-19
# 3         591    george_amick     \N   \N   George       Amick  1924-10-24
# 4         121        andretti     \N   \N  Michael    Andretti  1962-10-05
# ..        ...             ...    ...  ...      ...         ...         ...
# 153       449            ward     \N   \N   Rodger        Ward  1921-01-10
# 154       677            webb     \N   \N   Travis        Webb  1910-10-08
# 155       530          weiler     \N   \N    Wayne      Weiler  1934-12-09
# 156       563          weyant     \N   \N    Chuck      Weyant  1923-04-03
# 157       539  dempsey_wilson     \N   \N  Dempsey      Wilson  1927-03-11
#
#     nationality                                            url
# 0      American         http://en.wikipedia.org/wiki/Walt_Ader
# 1      American   http://en.wikipedia.org/wiki/Fred_Agabashian
# 2      American         http://en.wikipedia.org/wiki/Red_Amick
# 3      American      http://en.wikipedia.org/wiki/George_Amick
# 4      American  http://en.wikipedia.org/wiki/Michael_Andretti
# ..          ...                                            ...
# 153    American       http://en.wikipedia.org/wiki/Rodger_Ward
# 154    American       http://en.wikipedia.org/wiki/Travis_Webb
# 155    American      http://en.wikipedia.org/wiki/Wayne_Weiler
# 156    American      http://en.wikipedia.org/wiki/Chuck_Weyant
# 157    American    http://en.wikipedia.org/wiki/Dempsey_Wilson
#
# [158 rows x 9 columns]

# %% [markdown]
# <font size = "5">
#
# (c) Count unique values
#
# <font size = "3">
#
# - In this exercise use the function ```.read_sql()```
# - Count the number of unique "driverId" using ```COUNT(DISTINCT ...)``` <br>
# from the dataset "drivers"
#
# HINT: Include \\"driverId\\" in double quotations with an <br>
# escape character (see Lecture 20 for details) since <br>
# it has a mix of upper and lower case letters

# %%
# Write your own code
pd.read_sql(text("SELECT COUNT(DISTINCT \"driverId\") \
                 FROM drivers ;"),connection)
# Out:
#    count
# 0    857

# %% [markdown]
# <font size = "5">
#
# (d) Groupby + Aggregate + Sort
#
# <font size = "3">
#
# - In this exercise use the function ```.read_sql()```
# - Obtain the average of "milliseconds" by "driverId" using ```GROUP BY```
# - User ```ORDER BY ``` to sort on the average of milliseconds
#
# HINT: Include \\"driverId\\" in double quotations with an <br>
# escape character (see Lecture 20 for details) since <br>
# it has a mix of upper and lower case letters

# %%
# Write your own code
pd.read_sql(text("SELECT AVG(milliseconds) AS avg_milliseconds \
                 FROM lap_times \
                 GROUP BY \"driverId\" \
                 ORDER BY avg_milliseconds;"),connection)
# Out:
#     avg_milliseconds
# 0       22541.644444
# 1       22933.320000
# 2       23556.549296
# 3       23694.160920
# 4       23743.946667
# ..               ...
# 65     147575.454545
# 66     151408.205128
# 67     156576.937500
# 68     182538.593023
# 69     211286.047619
#
# [70 rows x 1 columns]

# %% [markdown]
# <font size = "5">
#
# (e) Merge two tables
#
# <font size = "3">
#
# - In this exercise use the function ```.read_sql()```
# - Merge the tables "lap_times" (primary) and "drivers" (secondary) <br>
# on "driverId" using ```LEFT JOIN``` on "driverId".
#
# HINT: Include \\"driverId\\" in double quotations with an <br>
# escape character (see Lecture 20 for details) since <br>
# it has a mix of upper and lower case letters

# %%
# Write your own code
pd.read_sql(text("SELECT * \
                 FROM lap_times \
                 LEFT JOIN drivers \
                 ON lap_times.\"driverId\" = drivers.\"driverId\" ;"),connection)
# Out:
#       raceId  driverId  stop  lap      time duration  milliseconds  driverId  \
# 0        841       153     1    1  17:05:23   26.898         26898       153
# 1        841        30     1    1  17:05:52   25.021         25021        30
# 2        841        17     1   11  17:20:48   23.426         23426        17
# 3        841         4     1   12  17:22:34   23.251         23251         4
# 4        841        13     1   13  17:24:10   23.842         23842        13
# ...      ...       ...   ...  ...       ...      ...           ...       ...
# 9629    1096       849     2   38  18:02:50   25.174         25174       849
# 9630    1096       840     2   40  18:04:44   21.802         21802       840
# 9631    1096       839     2   41  18:06:09   21.734         21734       839
# 9632    1096       846     2   42  18:07:36   21.559         21559       846
# 9633    1096       855     2   44  18:11:10   23.159         23159       855
#
#                driverRef number code  forename      surname         dob  \
# 0            alguersuari     \N  ALG     Jaime  Alguersuari  1990-03-23
# 1     michael_schumacher     \N  MSC   Michael   Schumacher  1969-01-03
# 2                 webber     \N  WEB      Mark       Webber  1976-08-27
# 3                 alonso     14  ALO  Fernando       Alonso  1981-07-29
# 4                  massa     19  MAS    Felipe        Massa  1981-04-25
# ...                  ...    ...  ...       ...          ...         ...
# 9629              latifi      6  LAT  Nicholas       Latifi  1995-06-29
# 9630              stroll     18  STR     Lance       Stroll  1998-10-29
# 9631                ocon     31  OCO   Esteban         Ocon  1996-09-17
# 9632              norris      4  NOR     Lando       Norris  1999-11-13
# 9633                zhou     24  ZHO    Guanyu         Zhou  1999-05-30
#
#      nationality                                                url
# 0        Spanish     http://en.wikipedia.org/wiki/Jaime_Alguersuari
# 1         German    http://en.wikipedia.org/wiki/Michael_Schumacher
# 2     Australian  http://en.wikipedia.org/wiki/Mark_Webber_(raci...
# 3        Spanish       http://en.wikipedia.org/wiki/Fernando_Alonso
# 4      Brazilian          http://en.wikipedia.org/wiki/Felipe_Massa
# ...          ...                                                ...
# 9629    Canadian       http://en.wikipedia.org/wiki/Nicholas_Latifi
# 9630    Canadian          http://en.wikipedia.org/wiki/Lance_Stroll
# 9631      French          http://en.wikipedia.org/wiki/Esteban_Ocon
# 9632     British          http://en.wikipedia.org/wiki/Lando_Norris
# 9633     Chinese           http://en.wikipedia.org/wiki/Guanyu_Zhou
#
# [9634 rows x 16 columns]
